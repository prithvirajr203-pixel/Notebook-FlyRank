# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvirajr203-pixel/Notebook-FlyRank/blob/main/work/notebooks/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/prithvirajr203-pixel/Notebook-FlyRank/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
import pandas as pd

# Show all variables currently in memory
print("Variables:")
print(list(globals().keys()))
# Out:
# Variables:
# ['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_i2', 'query', '_i3', 'pd', '_i4', '_i5', '_i6']

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
import pandas as pd

data_contract = pd.DataFrame({
    "Field": [
        "clicks",
        "impressions",
        "ctr",
        "position",
        "query",
        "landing_page",
        "future_clicks",
        "June 2026 data"
    ],
    "Bucket": [
        "Feature",
        "Feature",
        "Feature",
        "Feature",
        "Context",
        "Context",
        "Label",
        "Excluded"
    ],
    "Reason": [
        "Historical search performance available before prediction.",
        "Historical visibility of the page in Google Search.",
        "Calculated from historical clicks and impressions.",
        "Historical average search ranking.",
        "Identifies the search query.",
        "Identifies the landing page.",
        "Target variable to be predicted.",
        "Excluded because it is the final month and may cause data leakage."
    ]
})

display(data_contract)
# Out:
#             Field    Bucket                                             Reason
# 0          clicks   Feature  Historical search performance available before...
# 1     impressions   Feature  Historical visibility of the page in Google Se...
# 2             ctr   Feature  Calculated from historical clicks and impressi...
# 3        position   Feature                 Historical average search ranking.
# 4           query   Context                       Identifies the search query.
# 5    landing_page   Context                       Identifies the landing page.
# 6   future_clicks     Label                   Target variable to be predicted.
# 7  June 2026 data  Excluded  Excluded because it is the final month and may...

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
print(globals().keys())
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', '__builtin__', '__builtins__', '_ih', '_oh', '_dh', 'In', 'Out', 'get_ipython', 'exit', 'quit', '_', '__', '___', '_i', '_ii', '_iii', '_i1', '_i2', 'query', '_i3', 'pd', '_i4', '_i5', '_i6', '_i7', 'data_contract', '_i8', '_i9'])

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
#- The dataset contains only Google Search Console (GSC) search performance data and does not include user behavior after clicking the website (such as conversions or purchases).
3#- Historical data may be unbalanced because some queries or landing pages have fewer observations than others.
#- Early rows may contain only GSC data, so information from other analytics sources may be unavailable.
#- Time windows can overlap if not carefully filtered, which may introduce data leakage during model training.
#- The dataset cannot explain why rankings or clicks changed, only that the changes occurred.
# Out:
# 3

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
